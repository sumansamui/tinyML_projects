# %% [markdown]
# Open google drive
#
# new colab file
#
# Mount drive
#
# %cd drive/My Drive/
#
# !git clone https://github.com/sumansamui/tinyML_projects.git
#
# close the colab
#
# open tinyML_project folder --> open ML_framework notebook

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
# !git clone https://github.com/sumansamui/tinyML_projects.git
# Out:
# Cloning into 'tinyML_projects'...
# remote: Enumerating objects: 14, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 14 (delta 2), reused 8 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (14/14), 421.41 KiB | 11.09 MiB/s, done.
# Resolving deltas: 100% (2/2), done.
